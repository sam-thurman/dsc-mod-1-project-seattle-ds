# %%
# !which python
# Out:
# /Users/sam/opt/anaconda3/envs/oy-env/bin/python

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys
module_path = os.path.abspath(os.path.join(os.pardir, os.pardir))
if module_path not in sys.path:
    sys.path.append(module_path)
from src.data import data_collection
import psycopg2
import pandas as pd
DBNAME = "opportunity_youth"
conn = psycopg2.connect(dbname=DBNAME)

# %%
pd.read_sql("""
    SELECT column_name FROM information_schema.columns
    WHERE table_schema = 'public'
    AND table_name = 'wa_geo_xwalk'
""", conn)
# Out:
#      column_name
# 0     tabblk2010
# 1             st
# 2         stusps
# 3         stname
# 4            cty
# 5        ctyname
# 6           trct
# 7       trctname
# 8           bgrp
# 9       bgrpname
# 10          cbsa
# 11      cbsaname
# 12          zcta
# 13      zctaname
# 14         stplc
# 15     stplcname
# 16       ctycsub
# 17   ctycsubname
# 18       stcd116
# 19   stcd116name
# 20        stsldl
# 21    stsldlname
# 22        stsldu
# 23    stslduname
# 24      stschool
# 25  stschoolname
# 26       stsecon
# 27   dtseconname
# 28          trib
# 29      tribname
# 30          tsub
# 31      tsubname
# 32        stanrc
# 33    stanrcname
# 34         necta
# 35      nectname
# 36           mil
# 37       milname
# 38         stwib
# 39     stwibname
# 40      blklatdd
# 41      blklondd
# 42    createdate

# %%
puma_names_list = pd.read_sql("""
    SELECT puma_name FROM puma_names_2010
    WHERE puma='11610'
    OR puma='11611'
    OR puma='11612'
    OR puma='11613'
    OR puma='11614'
    OR puma='11615'
""", conn)['puma_name']
names_list = []
for name in puma_names_list:
    names_list.append(name)
names_list
# Out:
# ['King County (Central)--Renton City, Fairwood, Bryn Mawr & Skyway                                                                                                                                                                                                                                                                                                                                                                                                                                                    ',
# ...

# %%
pd.read_sql("""
    SELECT * FROM puma_names_2010
    WHERE state_fips = '53'
    LIMIT 10
""", conn)
# Out:
#   state_fips                                         state_name cpuma0010  \
# 0         53  Washington                                    ...      1030
# 1         53  Washington                                    ...      1031
# 2         53  Washington                                    ...      1032
# 3         53  Washington                                    ...      1032
# 4         53  Washington                                    ...      1032
# 5         53  Washington                                    ...      1032
# 6         53  Washington                                    ...      1032
# 7         53  Washington                                    ...      1032
# 8         53  Washington                                    ...      1032
# 9         53  Washington                                    ...      1033
#
#     puma    geoid    gisjoin  \
# 0  10100  5310100  G53010100
# 1  10200  5310200  G53010200
# 2  10300  5310300  G53010300
# 3  10400  5310400  G53010400
# ...

# %%
pd.concat(pd.read_sql("""
    SELECT puma_name, c.statefp, p.state_fips, w.st, puma, w.blklatdd, w.blklondd FROM ct_puma_xwalk c, puma_names_2010 p, wa_geo_xwalk w
    WHERE c.statefp = p.state_fips 
    AND p.state_fips = w.st
    AND puma = '11610'
    LIMIT 1
""", conn),
pd.read_sql("""
    SELECT puma_name, c.statefp, p.state_fips, w.st, puma, w.blklatdd, w.blklondd FROM ct_puma_xwalk c, puma_names_2010 p, wa_geo_xwalk w
    WHERE c.statefp = p.state_fips 
    AND p.state_fips = w.st
    AND puma = '11611'
    LIMIT 1
""", conn),
pd.read_sql("""
    SELECT puma_name, c.statefp, p.state_fips, w.st, puma, w.blklatdd, w.blklondd FROM ct_puma_xwalk c, puma_names_2010 p, wa_geo_xwalk w
    WHERE c.statefp = p.state_fips 
    AND p.state_fips = w.st
    AND puma = '11612'
    LIMIT 1
""", conn),
pd.read_sql("""
    SELECT puma_name, c.statefp, p.state_fips, w.st, puma, w.blklatdd, w.blklondd FROM ct_puma_xwalk c, puma_names_2010 p, wa_geo_xwalk w
    WHERE c.statefp = p.state_fips 
    AND p.state_fips = w.st
    AND puma = '11613'
    LIMIT 1
""", conn),
pd.read_sql("""
    SELECT puma_name, c.statefp, p.state_fips, w.st, puma, w.blklatdd, w.blklondd FROM ct_puma_xwalk c, puma_names_2010 p, wa_geo_xwalk w
    WHERE c.statefp = p.state_fips 
    AND p.state_fips = w.st
    AND puma = '11614'
    LIMIT 1
""", conn),
pd.read_sql("""
    SELECT puma_name, c.statefp, p.state_fips, w.st, puma, w.blklatdd, w.blklondd FROM ct_puma_xwalk c, puma_names_2010 p, wa_geo_xwalk w
    WHERE c.statefp = p.state_fips 
    AND p.state_fips = w.st
    AND puma = '11615'
    LIMIT 1
""", conn))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-53104448ac8b> in <module>
# ----> 1 pd.concat(pd.read_sql("""
#       2     SELECT puma_name, c.statefp, p.state_fips, w.st, puma, w.blklatdd, w.blklondd FROM ct_puma_xwalk c, puma_names_2010 p, wa_geo_xwalk w
#       3     WHERE c.statefp = p.state_fips
#       4     AND p.state_fips = w.st
#       5     AND puma = '11610'
#
# ~/opt/anaconda3/envs/oy-env/lib/python3.8/site-packages/pandas/core/reshape/concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     269     ValueError: Indexes have overlapping values: ['a']
#     270     """
# --> 271     op = _Concatenator(
#     272         objs,
#     273         axis=axis,
#
# ...

# %%
pd.read_sql("""
    SELECT * FROM wa_geo_xwalk
    LIMIT 10
""", conn)
# Out:
#         tabblk2010  st stusps  \
# 0  530330222014002  53     WA
# 1  530330218021030  53     WA
# 2  530330218021001  53     WA
# 3  530330218021018  53     WA
# 4  530330218021007  53     WA
# 5  530330218021000  53     WA
# 6  530330218021029  53     WA
# 7  530330007004015  53     WA
# 8  530330218021012  53     WA
# 9  530330218021017  53     WA
#
#                                               stname    cty  \
# 0  Washington                                    ...  53033
# 1  Washington                                    ...  53033
# 2  Washington                                    ...  53033
# 3  Washington                                    ...  53033
# 4  Washington                                    ...  53033
# 5  Washington                                    ...  53033
# 6  Washington                                    ...  53033
# 7  Washington                                    ...  53033
# 8  Washington                                    ...  53033
# ...

# %%
for name in pd.read_sql(f"""
    SELECT ctyname, blklatdd, blklondd
    FROM wa_geo_xwalk
    WHERE ctyname LIKE 'King County%'
    
    LIMIT 10
""", conn)['ctyname']:
    print(name)
# Out:
# King County, WA
# King County, WA
# King County, WA
# King County, WA
# King County, WA
# King County, WA
# King County, WA
# King County, WA
# King County, WA
# King County, WA
